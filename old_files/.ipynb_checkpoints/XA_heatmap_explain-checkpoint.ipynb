# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
import keras
import tensorflow
# Out:
# Using TensorFlow backend.

# %%
# Importing the libraries to use

import pandas as pd
import numpy as np
from keras.applications.vgg16 import decode_predictions
import seaborn as sns

from keras.applications.vgg16 import VGG16
import matplotlib.image as mpimg
from keras import backend as K
import matplotlib.pyplot as plt
# %matplotlib inline

from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input
import cv2

# %%
# Originial Codehttps://github.com/chuanhao01/XVis_Tool/blob/master/content/wiki/guide/Softmax_explain.pnghttps://github.com/chuanhao01/XVis_Tool/blob/master/content/wiki/guide/Softmax_explain.png
def cam(img_path):
    K.clear_session()
    model = VGG16(weights='imagenet')
    img=mpimg.imread(img_path)
    plt.imshow(img)
    img = image.load_img(img_path, target_size=(224, 224))
    x = image.img_to_array(img)
    x = np.expand_dims(x, axis=0)
    x = preprocess_input(x)
    preds = model.predict(x)
    predictions = pd.DataFrame(decode_predictions(preds, top=3)[0],columns=['col1','category','probability']).iloc[:,1:]
    argmax = np.argmax(preds[0])
    output = model.output[:, argmax]
    last_conv_layer = model.get_layer('block5_conv3')
    grads = K.gradients(output, last_conv_layer.output)[0]
    pooled_grads = K.mean(grads, axis=(0, 1, 2))
    iterate = K.function([model.input], [pooled_grads, last_conv_layer.output[0]])
    pooled_grads_value, conv_layer_output_value = iterate([x])
    for i in range(512):
        conv_layer_output_value[:, :, i] *= pooled_grads_value[i]
    heatmap = np.mean(conv_layer_output_value, axis=-1)
    heatmap = np.maximum(heatmap, 0)
    heatmap /= np.max(heatmap)
    img = cv2.imread(img_path)
    heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
    heatmap = np.uint8(255 * heatmap)
    heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
    hif = .8
    superimposed_img = heatmap * hif + img
    output = '/content/gdrive/My Drive/XAI_Project/output_images/out.jpg'
    cv2.imwrite(output, superimposed_img)
    img=mpimg.imread(output)
    plt.imshow(img)
    plt.axis('off')
    plt.title(predictions.loc[0,'category'].upper())
    return None

# %%
img_path = '../Sample_Images/dog_1.jpg'

cam(img_path)
# Out:
# ---------------------------------------------------------------------------
# UnknownError                              Traceback (most recent call last)
# <ipython-input-8-b80940a04842> in <module>
#       1 img_path = '../Sample_Images/dog_1.jpg'
#       2
# ----> 3 cam(img_path)
#
# <ipython-input-3-44f53bc2b022> in cam(img_path)
#       9     x = np.expand_dims(x, axis=0)
#      10     x = preprocess_input(x)
# ---> 11     preds = model.predict(x)
#      12     predictions = pd.DataFrame(decode_predictions(preds, top=3)[0],columns=['col1','category','probability']).iloc[:,1:]
#      13     argmax = np.argmax(preds[0])
#
# ~/anaconda3/lib/python3.7/site-packages/keras/engine/training.py in predict(self, x, batch_size, verbose, steps, callbacks, max_queue_size, workers, use_multiprocessing)
#    1460                                             verbose=verbose,
#    1461                                             steps=steps,
# ...

# %% [markdown]
# # Trying to understand the code
#
# The blocks will be split into large sections and I (hopefully) will be commenting
# on the code as I write from the guys notebook.
#
# ---

# %% [markdown]
# ## For the Image

# %%
# Processing the input image
img_path = '/content/gdrive/My Drive/XAI_Project/sample_images/dog_2.jpg'

# Code to plot the image out
img=mpimg.imread(img_path)
print(img.shape,'hello')
plt.imshow(img)

# Processing the image
img = image.load_img(img_path, target_size=(224, 224)) # Resize the img to model input
x = image.img_to_array(img) # making it into a numpy array
x = np.expand_dims(x, axis=0) # making it into a batch format
print('Batch form of the image')
print(x.shape)

# Keras preprocessing the image
x = preprocess_input(x)
print(x.shape)
# Out:
# (512, 768, 3) hello
# Batch form of the image
# (1, 224, 224, 3)
# (1, 224, 224, 3)

# %% [markdown]
# ---

# %% [markdown]
# ##For Passing the image thorugh a trained model

# %%
model = VGG16(weights = 'imagenet') # initalising the model with pre-trained weights on imageNet
preds = model.predict(x) # using the model to predict based on input image

# own code below
print('Dimension of code:')
print(preds.shape, '\nNotice how the 1000 columns map to the 1000 classes')
print()

decoded_preds = decode_predictions(preds, top=3)
print('Dedcoded predictions: ')
print(decoded_preds) # the array is nested
print()
predictions = pd.DataFrame(decoded_preds[0], columns = ['id_col', 'Category', 'Prob'])
predictions = predictions.drop('id_col', axis=1) # dropping the id_col
print('Predictions in table form')
print(predictions)
print()

# Not sure what argmax is
# returns the indice of the max number
argmax = np.argmax(preds[0])
print('The indice of the max number in the predictions I guess?')
print(argmax)
print()

# Looking at the output of a layer. Note, to look at the tensor output of any layer we can do `model.layers[index].output` to get the tensor
# In this case, model.output gives back the tensor of the final dense, softmax layer
output = model.output
print('The tensor of the final output:')
print(output)
print()
print('Getting the tensor with the specfic output prediction neurone:')
output = output[:, argmax]
print(output)
print()

# DEBUGGING CODE
print('DEBUGGING CODE')
print(preds.shape)
print(model.summary())
# model_output = model.output
# print(model_output)
print(model.input)
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:66: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:541: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4432: The name tf.random_uniform is deprecated. Please use tf.random.uniform instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4267: The name tf.nn.max_pool is deprecated. Please use tf.nn.max_pool2d instead.
#
# ...
# 553467904/553467096 [==============================] - 16s 0us/step
# ...

# %% [markdown]
# ---

# %% [markdown]
# ##Trying to map the output of the prediction, to the weight activation and the last conv layer.
#
# Then making a final keras function to map a new image

# %%
# Now we get the final conv layer
# Both methods shown below gets the last conv layer, only the top one uses indices while the bottom one use the id of the layer from model.summary 

# last_conv_layer = model.layers[17]
last_conv_layer = model.get_layer('block5_conv3')
print('The last conv layer tensor:')
print(last_conv_layer)
print()
print('Now we are only taking the tf backend tensor to get the gradient:')
last_conv_layer = last_conv_layer.output
print(last_conv_layer)
print()

# Big Note: From this point, I am not sure what the code is doing alr

# Getting the gradeint of the loss(output) w.r.t the variables(last_conv_layer)
# Side thought: I think if I change the layer in which I am taking the gradient, I can change which layer I am trying to find the activation for

# Note im am not sure what the gradient func is doing
# K is for keras.backend
# Also the function returns the tensor in a array, thus we only want the tensor
grads = K.gradients(output, last_conv_layer)[0]
print('The tensor repr of the gradient: ')
print(grads)
print()

# Getting the mean tensor of the gradients over the specific feature map channel, at the end has a shape of (512, )
# I think this is taking the average along the dims of the final image, and reducing it to a 2-D tensor, with the mean gradients
pooled_grads = K.mean(grads, axis = (0,1,2))
print('Getting the mean tensor, getting mean along the l and w dims, end up with a (512,) tensor: ')
print(pooled_grads)

# Now we are making the keras function to iterate and access the values in the tensor
iterate = K.function([model.input], [pooled_grads, last_conv_layer])
# Out:
# The last conv layer tensor:
# ...
#
# Now we are only taking the tf backend tensor to get the gradient:
# Tensor("block5_conv3/Relu:0", shape=(?, 14, 14, 512), dtype=float32)
#
# The tensor repr of the gradient:
# Tensor("gradients/block5_pool/MaxPool_grad/MaxPoolGrad:0", shape=(?, 14, 14, 512), dtype=float32)
#
# Getting the mean tensor, getting mean along the l and w dims, end up with a (512,) tensor:
# Tensor("Mean:0", shape=(512,), dtype=float32)

# %% [markdown]
# ---

# %% [markdown]
# ##Now mapping the function to the image

# %%
# Runing the keras function over a new image.

# What I think is happening:
# The input image, a numpy array/tensor is passed thorugh the function which takes the prediction and did what I did above to get the respective tensors
# Then it outputs the numpy array/tensors accordingly
pooled_grads_value, conv_layer_output_value = iterate([x])
print('The pooled_grads_values and conv layer outputs')
print(type(pooled_grads_value), type(conv_layer_output_value))
print(pooled_grads_value.shape, conv_layer_output_value.shape)
print()
print('Some sample values fropm the 2 outputs: ')
print(pooled_grads_value[:5], conv_layer_output_value[0][0][0][:5])

# Multiply each channel('layer') of the last_conv_layer with the respective scalar in the pooled_grad_value
for i in range(len(pooled_grads_value)):
  conv_layer_output_value[0, :, :, i] *= pooled_grads_value[i]
# Out:
# The pooled_grads_values and conv layer outputs
# <class 'numpy.ndarray'> <class 'numpy.ndarray'>
# (512,) (1, 14, 14, 512)
#
# Some sample values fropm the 2 outputs:
# [-8.2465949e-06 -6.9061698e-06 -4.2534043e-06 -1.1473243e-06
#  -4.0263030e-06] [0. 0. 0. 0. 0.]

# %% [markdown]
# ---

# %% [markdown]
# ##Plotting the heatmap

# %%
# This part takes the mean along one of the l or w axis, so the heatmap is a 2-D repr with 14 mean value of each l or w and 512 feature maps
heatmap = np.mean(conv_layer_output_value, axis=-1)

print('Taking mean along one of the l or w axis: ')
print('Before dims: ', conv_layer_output_value.shape)
print('After dims', heatmap.shape)
print()

# IDK what this is doing, the nparray is literally the same
heatmap = np.maximum(heatmap, 0)

# You can check using the code below
# max_heatmap = np.maximum(heatmap, 0)
# print(max_heatmap[(max_heatmap == heatmap) == False])

# Actual max? This finds the maxium of the whole 2-D array/tensor??
# Is it trying to regularise the whole tensor?
heatmap /= np.max(heatmap)


# plotting the heatmap
print(heatmap.shape)
plt.matshow(heatmap[0])
plt.show()
# Out:
# Taking mean along one of the l or w axis:
# Before dims:  (1, 14, 14, 512)
# After dims (1, 14, 14)
#
# (1, 14, 14)

# %% [markdown]
# ---

# %% [markdown]
# ##Applying heatmap onto img

# %%
img = cv2.imread(img_path)

print('Previous dims of the heatmap:')
print(heatmap.shape)
print()

# resizing the heatmap to the size of the img
heatmap = cv2.resize(heatmap[0], (img.shape[1], img.shape[0]))
print('Dims of the heatmap after scaling')
print(heatmap.shape)
print()

# Making the heatmap scale from 0-255
heatmap = np.uint8(255 * heatmap)

# Apply heatmap to the img
heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
hif = 0.8 # heatmap intensity filter
superimposed_img = heatmap * hif + img

# superimposed_img /= 255.

# plt.imshow(superimposed_img)

# cv2.imwrite('/content/gdrive/My Drive/XAI_Project/output_images/out.jpg', superimposed_img)

# img = mpimg.imread('/content/gdrive/My Drive/XAI_Project/output_images/out.jpg')

# plt.imshow(img)
# Out:
# Previous dims of the heatmap:
# (512, 768, 3)
#
# Dims of the heatmap after scaling
# (512, 768)

# %% [markdown]
# ---

# %% [markdown]
# #Implementing my own function

# %%
# New function I am developing with custom inputs.
# Input Params:
# img_path = absolute path to the input image into the model
# out_path = absolute path for the output image with the heatmap applied
# model = keras loaded model
# layer_name = the string value of the conv layer u want to generate the heatmap from
# input_size = a tuple of the form (x, y) where it is the dimensions of the input to the CNN
def improvedCam(img_path, out_path, model, layer_name, input_size):
  # loading the img in from path
  img = image.load_img(img_path, target_size = input_size)
  # changing the image into a keras form bath in 4-D
  x = image.img_to_array(img)
  x = np.expand_dims(x, axis=0)
  x = preprocess_input(x)
  print('After preprocessing image dims: ', x.shape)
  print()
  # Getting the predictions from the model
  # preds is the coded preds and prediction is the string repr of the prediction
  preds = model.predict(x)
  predictions = decode_predictions(preds, top=1)[0][0]
  predictions = predictions[1]
  # Getting the tensor of all weights of the final dense layer
  output = model.output
  # getting the indice/position of the weight that contributed the most to the classification
  argmax = np.argmax(preds[0])
  # isolating the weight that contributed the most to the classification in the output tensor
  output = output[:, argmax]
  # getting the conv_layer to apply the heatmap to
  conv_layer = model.get_layer(layer_name).output
  # Getting the gradients of the most activated weight w.r.t. the conv_layer
  # Also getting the mean of the gradients per feature map 
  grads = K.gradients(output, conv_layer)[0]
  pooled_grads = K.mean(grads, axis = (0, 1, 2))
  # Making the Keras function
  iterate = K.function([model.input], [pooled_grads, conv_layer])
  # Getting the pooled_grads and conv layer w.r.t. the input img
  pooled_grads_value, conv_layer_output_layer = iterate([x])
  for i in range(len(pooled_grads_value)):
    conv_layer_output_layer[0, :, :, i] *= pooled_grads_value[i]
  # Generating the heatmap based on the grads and conv_layer
  heatmap = np.mean(conv_layer_output_layer, axis=-1)[0]
  # Im still confused about the np.maximum funct
  heatmap = np.maximum(heatmap, 0)
  heatmap /= np.max(heatmap)
  # Loading the img using cv2
  img = cv2.imread(img_path)
  # resizing and normalizing the heatmap
  heatmap = cv2.resize(heatmap, (img.shape[1], img.shape[0]))
  heatmap = np.uint8(heatmap * 255)
  # applying the heatmap
  heatmap = cv2.applyColorMap(heatmap, cv2.COLORMAP_JET)
  hif = 0.8
  superimposed_image = heatmap * hif + img
  cv2.imwrite(out_path, superimposed_image)
  out_img = mpimg.imread(out_path)
  plt.imshow(out_img)
  plt.axis('off')
  plt.title(predictions)

# %%
# Importing models from keras
from keras.applications.inception_resnet_v2 import InceptionResNetV2
from keras.applications.xception import Xception
# Out:
# Using TensorFlow backend.

# %%
model = InceptionResNetV2(weights = 'imagenet')
model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:4271: The name tf.nn.avg_pool is deprecated. Please use tf.nn.avg_pool2d instead.
#
# ...
# 225214464/225209952 [==============================] - 7s 0us/step
# Model: "inception_resnet_v2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ...
# input_2 (InputLayer)            (None, 299, 299, 3)  0
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, 149, 149, 32) 864         input_2[0][0]
# __________________________________________________________________________________________________
# batch_normalization_5 (BatchNor (None, 149, 149, 32) 96          conv2d_5[0][0]
# __________________________________________________________________________________________________
# ...

# %%
img_path = '/content/gdrive/My Drive/XAI_Project/sample_images/cat_2.jpg'
out_path = '/content/gdrive/My Drive/XAI_Project/output_images/out.jpg'
# model = InceptionResNetV2(weights = 'imagenet')
layer_name = 'block8_10_conv'
input_size = (299, 299)

a = improvedCam(img_path, out_path, model, layer_name, input_size)
# Out:
# After preprocessing image dims:  (1, 299, 299, 3)
